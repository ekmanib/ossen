# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import networkx as nx
import seaborn as sns
import geopandas as gpd
from shapely.geometry import Point


sns.set(style='white', rc={'figure.figsize':(8, 8)})

# %% [markdown]
# ## Read in and wrangling the data

# %%
metro = pd.read_csv('../data/medellin_metro.csv', encoding='latin-1')

# Print out data samples
metro.head().T
# Out:
#                                                       0  \
# stop                                              Bello
# line                                                  A
# comuna_name   Bello-Comuna 03                         '
# comuna_index                                          8
# macrozona                                             8
# municipality                                      bello
# muni_index                                            3
# Lattitude                                      6.337778
# Longitude                                    -75.544444
# type                                              Metro
# transfer                                            NaN
# transfer2                                           NaN
#
#                                                       1  \
# stop                                       Palos verdes
# line                                                 L1
# comuna_name   Manrique                                '
# comuna_index                                          9
# macrozona                                            13
# municipality                                   medellin
# muni_index                                            1
# Lattitude                                      6.330278
# Longitude                                    -75.553611
# type                                  Bus rapid transit
# transfer                                             L1
# transfer2                                           NaN
#
#                                                       2  \
# stop                                             Gardel
# line                                                 L1
# comuna_name   Manrique                                '
# comuna_index                                          9
# macrozona                                            13
# municipality                                   medellin
# muni_index                                            1
# Lattitude                                      6.315833
# Longitude                                    -75.555417
# type                                  Bus rapid transit
# transfer                                             L1
# transfer2                                           NaN
#
#                                                       3  \
# stop                                           Manrique
# line                                                 L1
# comuna_name   Manrique                                '
# comuna_index                                          9
# macrozona                                            13
# municipality                                   medellin
# muni_index                                            1
# Lattitude                                      6.300278
# Longitude                                    -75.558472
# type                                  Bus rapid transit
# transfer                                             L1
# transfer2                                           NaN
#
#                                                       4
# stop                                     Las Esmeraldas
# line                                                 L1
# comuna_name   Manrique                                '
# comuna_index                                          9
# macrozona                                            13
# municipality                                   medellin
# muni_index                                            1
# Lattitude                                      6.290597
# Longitude                                    -75.564258
# type                                  Bus rapid transit
# transfer                                             L1
# transfer2                                           NaN

# %%
# Read in the data
comunas_df = pd.read_csv('../data/comunas.csv', 
                         encoding='latin-1')
populat_df = pd.read_csv('../data/comunas_pop.csv', 
                         encoding='latin-1')
stratum_df = pd.read_csv('../data/comunas_stratum.csv', 
                         encoding='latin-1')
firms_df = pd.read_csv('../data/comunas_firms.csv',
                         encoding='latin-1')

# Define tweaking function
def tweak_df(df):
    return (df
     .rename(columns=lambda c: c.strip().lower().replace(' ', '_'))
     .pipe(extract_names)
     .assign(**{c:lambda df_, c=c: (df_[c]
                                     .str.title()
                                     .str.replace('\'', '')
                                     .str.strip())
                for c in columns_object})
     )

# Define other useful functions
def extract_names(df):
    globals()['columns_number'] = df.select_dtypes('number').columns
    globals()['columns_object'] = df.select_dtypes(exclude='number').columns
    return df

def normalize(ser):
    return (ser - min(ser)) / (max(ser) - min(ser)) * 650 + 50

def normalize_1(ser):
    ser = ser.dropna()
    return (ser - min(ser)) / (max(ser) - min(ser))
    
# Reformat each of the datasets
comunas_df = tweak_df(comunas_df)
populat_df = tweak_df(populat_df)
stratum_df = tweak_df(stratum_df)
firms_df = tweak_df(firms_df)

# %%
commutes_df = pd.read_csv('../data/comunas_commutes.csv', 
                      names=['source', 'target', 'strength'])
commutes_df = commutes_df.loc[~(commutes_df.source == commutes_df.target)].groupby(['source' ,'target']).sum().reset_index()

gmaps_df = pd.read_csv('../data/comunas_gmaps.csv',
                       skiprows=1,
                       names=['travel_time_min', 'mode', 'source', 'target'])

edges_df = (commutes_df
 .merge(gmaps_df, how='inner', on=['source', 'target'])
 .assign(flow_size=lambda df_: normalize_1(df_.strength),
         travel_time_min=lambda df_: df_.travel_time_min.replace(np.inf, np.nan),
         travel_size=lambda df_: normalize_1(df_.travel_time_min),)
)

# %%
commutes_df
# Out:
#       source  target  strength
# 0          1       2        44
# 1          1       3        55
# 2          1       4        42
# 3          1       7        47
# 4          1       8         3
# ...      ...     ...       ...
# 3276      66      54         1
# 3277      66      55         3
# 3278      66      56         1
# 3279      66      59         2
# 3280      66      64        10
#
# [3281 rows x 3 columns]

# %%
nodes_df = (comunas_df
 .merge(populat_df,
        how='left',
        on=['comuna_index', 'muni_index'])
 .merge(stratum_df,
        how='left',
        on=['comuna_index', 'muni_index'])
 .merge(firms_df,
        how='left',
        on=['comuna_index', 'muni_index'])
 .set_index('comuna_index')
 .assign(pop_size=lambda df_: normalize(df_.population),
         str_size=lambda df_: normalize(df_.stratum),
         fir_size=lambda df_: normalize(df_.num_firms),
         inflow=normalize(commutes_df.groupby('target')['strength'].sum()))
)

metro = (metro
 .pipe(tweak_df) 
 # appending the shapefile identifier
 .merge(nodes_df,
        how='left',
        on=['comuna_index', 'muni_index', 'comuna_name', 'municipality'])
)

# %%
# Read in shape file to geopandas data frmae
geoms = gpd.read_file('../data/comunas_boundaries.zip')

# %% [markdown]
# ## Understading the spatial distribution of the data

# %%
# Create the network from the edge list
# G = nx.from_pandas_edgelist(edges_df, create_using=nx.DiGraph, edge_attr=True)
G = nx.from_pandas_edgelist(edges_df, edge_attr=True)

# Create the dictionary with nodes positions
pos = {i: np.array([d.get('comuna_longitude'), 
                    d.get('comuna_latitude')]) 
       for i, d in comunas_df.set_index('comuna_index').iterrows()}

# Add node metadata
for i, r in nodes_df.iterrows():
    G.nodes[i]['name'] = r['comuna_name']
    G.nodes[i]['population'] = r['pop_size']
    G.nodes[i]['stratum'] = r['str_size']
    G.nodes[i]['firms'] = r['fir_size']
    G.nodes[i]['inflow'] = r['inflow']

# %% [markdown]
# ## Exploring Comunas By Population, Stratum, and Economic Activity

# %%
_ = gpd.plotting.plot_series(geoms.geometry, color='#fad9d9')
_ = nx.draw_networkx_nodes(G, 
                           pos=pos, 
                           node_color='#b51b10',
                           edgecolors='#4d0904', 
                           alpha=0.75,
                           node_size=[d.get('population', 100) for n, d in G.nodes(data=True)],)
_ = nx.draw_networkx_edges(G, 
                           pos=pos,  
                           width=0.3,
                           alpha=0.2)

_ = plt.axis('off')

# %%
_ = gpd.plotting.plot_series(geoms.geometry, color='#fad9d9')
_ = nx.draw_networkx_nodes(G, 
                           pos=pos,
                           node_color='#b51b10',
                           edgecolors='#4d0904', 
                           alpha=0.75,
                           node_size=[d.get('stratum', 100) for n, d in G.nodes(data=True)],)
_ = nx.draw_networkx_edges(G, 
                           pos=pos,  
                           width=0.3,
                           alpha=0.2)

_ = plt.axis('off')

# %%
_ = gpd.plotting.plot_series(geoms.geometry, color='#fad9d9')
_ = nx.draw_networkx_nodes(G, 
                           pos=pos,
                           node_color='#b51b10',
                           edgecolors='#4d0904', 
                           alpha=0.75,
                           node_size=[d.get('firms', 100) for n, d in G.nodes(data=True)],)
_ = nx.draw_networkx_edges(G, 
                           pos=pos,  
                           width=0.3,
                           alpha=0.2)

_ = plt.axis('off')

# %% [markdown]
# ## Exploring Connections By Travel Frequency and Commute Duration

# %%
_ = gpd.plotting.plot_series(geoms.geometry, color='#fad9d9')
_ = nx.draw_networkx_nodes(G, 
                           pos=pos,
                           node_color='#b51b10',
                           edgecolors='#4d0904', 
                           alpha=0.5,
                           node_size=100,)
_ = nx.draw_networkx_edges(G, 
                           pos=pos, 
                           width=[d.get('flow_size') * 1.5 for _, _, d in G.edges(data=True)],
                           alpha=0.8)

_ = plt.axis('off')

# %%
_ = gpd.plotting.plot_series(geoms.geometry, color='#fad9d9')
_ = nx.draw_networkx_nodes(G, 
                           pos=pos,
                           node_color='#b51b10',
                           edgecolors='#4d0904', 
                           alpha=0.5,
                           node_size=100,)
_ = nx.draw_networkx_edges(G, 
                           pos=pos, 
                           width=[d.get('travel_size', 0) for _, _, d in G.edges(data=True)],
                           alpha=0.2)

_ = plt.axis('off')

# %% [markdown]
# ##

# %%
fig, ax = plt.subplots(figsize=(24, 24))

_ = gpd.plotting.plot_series(geoms.geometry, ax=ax, color='#fad9d9')
_ = ax.plot(metro.longitude, metro.lattitude, marker='^', linestyle='none')
_ = nx.draw_networkx_nodes(G, 
                           pos=pos,
                           ax=ax,
                           node_color='#b51b10',
                           edgecolors='#4d0904', 
                           alpha=0.5,
                           node_size=[d.get('inflow', 100) * 1.5 for n, d in G.nodes(data=True)],)
_ = nx.draw_networkx_edges(G, 
                           pos=pos, 
                           ax=ax,
                           width=[d.get('flow_size') * 1.5 for _, _, d in G.edges(data=True)],
                           alpha=0.8)
_ = nx.draw_networkx_labels(G, pos=pos)


_ = plt.axis('off')

# %%
metro[metro.comuna_index==58]
# Out:
#       stop line      comuna_name  comuna_index  macrozona municipality  \
# 55  Madera    A  Bello-Comuna 02            58         28     Medellin
#
#     muni_index  lattitude  longitude   type  ... comuna_longitude  \
# 55           1   6.231879   -75.5859  Metro  ...              NaN
#
#    comuna_latitude  macrozona__shapefile  population  stratum  num_firms  \
# 55             NaN                   NaN         NaN      NaN        NaN
#
#     pop_size  str_size  fir_size  inflow
# 55       NaN       NaN       NaN     NaN
#
# [1 rows x 22 columns]

# %% [markdown]
# ## TODO:
#
# - where is it possible to cause the biggest impact
